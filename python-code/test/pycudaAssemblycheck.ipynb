# %%
# Pycuda DCA
#---------------
# This is a script to solve for the motion of a 
# massive rod double pendulum using DCA and pycuda

import numpy as np
import math
from scipy.integrate import odeint
import matplotlib.pyplot as plt

import pycuda.driver as cuda
import pycuda.autoinit
from pycuda.compiler import SourceModule

import MBstructs as MB
import MultiBodyFuncts as MBF
import sys

# %matplotlib inline

# %%
mod = SourceModule("""
/*This is a cuda kernal which calculates the initial zeta values for all bodies
in a pendulum chain*/
#include <cuda.h>
#include <stdio.h>
#define n 2

//Function Prototypes

__device__ void PrintMat61(float A[6][6], int nn );
__device__ void PrintMat66(float A[6][6], int nn);
__device__ void MSsetup(float Minv[6][6],float S[6][6],int row, int col, float m, float I[],int Iindex,int i1);
__device__ void Fa(float S[6][6],float w, float r[], float m,int row, int col);
__device__ void transpose(float S[6][6],int row, int col);
__device__ void makeS(float S[6][6],float *r);
__device__ void zab(float r[],float z[6][6],float Minv[6][6],float S[6][6], int row, int col);
__device__ void zaa(float r[],float z[6][6],float Minv[6][6],float S[6][6], int row, int col);
__device__ void r02(float r[], float angle,float L);
__device__ void r01(float r[], float angle,float L);
__device__ void DCM(float angle, float **B);
__device__ void Mat61Mult(float A[6][6], float B[6][6], float C[6][6],int row, int col);
__device__ void Mat66Mult(float A[6][6], float B[6][6], float C[6][6],int row, int col);

__global__ void Assemble(float oldzs[],float newzs[],int odd,int nn)
{
    __shared__ float z1[6][6];
    __shared__ float z2[6][6];
    __shared__ float A[6][6]
    //Variable Declarations
    const int i1 = blockIdx.x;
    const int row = threadIdx.y;
    const int col = threadIdx.x;
    
    //indices to read the old zs
    const int r111=col+row*nn*26+i1*52;
    const int r112=r111+6;
    const int r113=r112+6; //only col = 0 can read
    const int r121=r113+1;
    const int r122=r121+6;
    const int r123=r122+6; //only col= 0 can read
    
    const int r211=r123+1;
    const int r212=r211+6;
    const int r213=r212+6;
    const int r221=r213+1;
    const int r222=r221+6;
    const int r223=r222+6;
    
    int rowlen;
    //indices to write the new zs
    if(odd)
    {
        rowlen = ((nn/2)+1)*26;
    }
    else
    {
        rowlen = (nn/2)*26;
    }
    
    const int i11 = col+row*rowlen+i1*26;
    const int i12=i11+6;
    const int i13=i12+6; //only col=0 can write
    const int i21=i13+1;
    const int i22=i21+6;
    const int i23=i22+6; //only col = 0 can write
    
    /**************Get the intermediate quantity W***************/
    z1[row][col]=oldZs[r211];
    z2[row][col]=oldZs[r122];
    
    get_W(z1,z2,A,row,col);
    
    /**A now holds W, so W can be used to find all newZs excpt z13 and z23***/
    z1[row][col]=oldZs[r112];//z12 for body 1
    z2[row][col]=oldZs[r212];//z12 for body 2
    Mat66Mult(A,z2,z2,row,col);
    Mat66Mult(z1,z2,z2,row,col);//z2 now holds the new z12
    newZs[i12]=z2[row][col]
    
    //next find z11
    z2[row][col]=oldZs[r121];//z21 for body 1
    Mat66Mult(A,z2,z2,row,col);
    Mat66Mult(z1,z2,z2);
    z1[row][col]=oldZs[r111];
    z2[row][col]=z1[row][col]-z2[row][col];
    newZs[i11]=z2[row][col];
}
__device__ void get_W(float z1[6][6], float z2[6][6], float W[6][6],int row, int col)
{
    get_X_pend(z1,z2,W,row,col);
    invert_X(W,z1,row,col);
    make_W_pend(W,z1,row,col);
}

__device__ void get_X_pend(float z1[6][6], float z2 [6][6], float D[6][6],int row , int col)
{
    z1[row][col]=z1[row][col]+z2[row][col];
    
    set_D_pend(D);
    Mat66Mult(z1,D,z1,row,col);
    set_Dt_pend(D);
    Mat66Mult(D,z1,D,row,col);
}
__device__ void set_D_pend(float D[6][6],int row,int col)
{
    D[row][col]=0;
    if(row+col==0)
    {
        D[0][0]=1;
        D[1][1]=1;
        D[3][2]=1;
        D[4][3]=1;
        D[5][4]=1;
    }
}
__device__ void set_Dt_pend(float D[6][6],int row,int col)
{
    D[row][col]=0;
    if(row+col==0)
    {
        D[0][0]=1;
        D[1][1]=1;
        D[2][3]=1;
        D[3][4]=1;
        D[4][5]=1;
    }
}

__device__ void invert_X(float X[6][6], float A[6][6],int row, int col)
{
     int s;
     int t;
     float temp;
     float temp2;
     A[row][col]=0;
     if (row==col)
     {
          A[row][col]=1;
         for(s=0;s<5;s++)
         {
            temp=X[s][s];
            X[s][col]=(X[s][col]/temp);
            A[s][col]=(A[s][col]/temp);
            for(t=0;t<5;t++)
            {
                if(s != j)
                {
                     temp2=X[j][s]
                     X[j][col]=X[j][col]-(X[s][col]*temp2);
                     A[j][col]=A[j][col]-(A[s][col]*temp2);
                }
            }
          }
        }
        X[row][col]=A[row][col];
}
__device__ void make_W_pend(float Xinv[6][6], float D[6][6],int row , int col)                    
{
    if (row == 5 || col==5)
    {
         Xinv[row][col]=0
    }
    
    set_Dt_pend(D);
    Mat66Mult(Xinv,D,Xinv,row,col);
    set_Dt_pend(D);
    Mat66Mult(D,Xinv,Xinv,row,col);
}















__global__ void Initialize(float state[],float m[], float l[],float I[],float Zetas[])
{
    //Variable Declarations
	const int i1 = blockIdx.x;
	const int row = threadIdx.y;
	const int col = threadIdx.x;
    const int Iindex = blockIdx.x*3+row*3*n+col;
    const int i11 = col+row*26*n+i1*26;
    const int i12=i11+6;
    const int i13=i12+6; //only col=0 can write
    const int i21=i13+1;
    const int i22=i21+6;
    const int i23=i22+6; //only col = 0 can write
    __shared__ float z[6][6];
    __shared__ float Minv[6][6];
    __shared__ float S[6][6];
    __shared__ float r[3];
    __shared__ float q;
    __shared__ float w;
    //////////////////q and w//////////////////////////////////////
    //To get q and w, either this:

    int i = 0;
    while (i <= i1)
    {
        q+=state[i];
        w+=state[i+n];
        i++;
    }
   
    /*
    //or this, but only if less than 36 bodies:

    __shared__ float lcl_state[2*n];
    if (index < 2*n)
    {
        lcl_state[index]=state[index];
    }
    */
    //then add them up to get the right number

    ////////////////Inverse Mass Matrix and shifter setup//////////////////////////////////
    MSsetup(Minv,S,row,col,m[i1],I,Iindex,i1);
    
    
    
    ////////////////////DCM/////////////////////////////////////////
    //Dont need a dcm because it is planar, so for now to avoid memory 
    //usage, Im not using it.
    //DCM(q,C)
    
    ///////////////////z11/////////////////////////////////////////
    z[row][col]=0;
    r01(r,q,l[i1]);
 
    zaa(r,z,Minv,S,row,col);
    
    Zetas[i11]=z[row][col];
    //////////////////z12//////////////////////////////////////////
    //S is now S10, Minv is S10*Minv and z is z11
    z[row][col]=0;
    r02(r,q,l[i1]);
    zab(r,z,Minv,S,row,col);

    Zetas[i12]=z[row][col];
    ////////////////z13///////////////////////////////////////
    //S is S02, Minv is S10*Minv, z is z12
    r01(r,q,l[i1]);
    Fa(S,w,r,m[i1],row,col);
    Mat61Mult(Minv,S,z,row,col);
    if (col==0)
    {
        Zetas[i13]=z[row][col];
    }
    
    ////////////////z22///////////////////////////////////
    z[row][col]=0;
    MSsetup(Minv,S,row,col,m[i1],I,Iindex,i1);
    r02(r,q,l[i1]);
    zaa(r,z,Minv,S,row,col);
    Zetas[i22]=z[row][col];
    //////////////////z21/////////////////////////////////
    //S is now S20 Minv is S20*Minv and z is z22
    z[row][col]=0;
    r01(r,q,l[i1]);
    zab(r,z,Minv,S,row,col);
    Zetas[i21]=z[row][col];
    ///////////////////z23/////////////////////////////////////
    //S is S01, Minv is S20*Minv and z is z21
    r02(r,q,l[i1]);
    Fa(S,w,r,m[i1],row,col);
    Mat61Mult(Minv,S,z,row,col);
    if (col==0)
    {
        Zetas[i23]=z[row][col];
    }
}
    
/**********************Zeta Calculation Functions**************/

//Function used to calculate z11 and z22
__device__ void zaa(float r[],float z[6][6],float Minv[6][6],float S[6][6], int row, int col)
{
     
     if ((row+col)==0)
     {
          makeS(S,r);
     }
   
   
     Mat66Mult(Minv,S,z,row,col);
     
     transpose(S,row,col);
     Mat66Mult(S,z,z,row,col);
     Mat66Mult(S,Minv,Minv,row,col);
}

//Function used to calculate z12 and z21
__device__ void zab(float r[],float z[6][6],float Minv[6][6],float S[6][6],int row , int col)
{    
    if (row+col==0)
     {
          makeS(S,r);
     }
    if (row>2 && col<3)
    {
         S[row][col]=0;
    }
    Mat66Mult(Minv,S,z,row,col);
}

/**********************Matrix Setup Functions******************/

//Creates a shifter matrix with the given position vector r
__device__ void makeS(float S[6][6],float r[])
{
     S[0][4]=-1*r[2];
     S[0][5]=r[1];
     S[1][3]=r[2];
     S[1][5]=-1*r[0];
     S[2][3]=-1*r[1];
     S[2][4]=r[0];
     
}


//Setup the inverse mass and shifter matrices.
__device__ void MSsetup(float Minv[6][6],float S[6][6],int row , int col,float m, float I[],int Iindex,int i1)
{
    Minv[row][col]=0;
    S[row][col]=0;
    if (row<3 && col==row)
    {
        Minv[row][col]=1/(I[Iindex]);
        Minv[row+3][col+3]=1/m;
    }
    if (col==row)
    {
        S[row][col]=1;
    }  
}

//set up the state dependant force vector Fa
__device__ void Fa(float S[6][6],float w, float r[], float m,int row, int col)
{
 float g = 9.81;
    if (col == 0)
    {
         S[row][col]=0;
    }
    if (row +col == 0)
    {
         S[3][0]=-m*w*w*r[0];
         S[4][0]=-g*m-m*w*w*r[1];
    }
}

//Function to find the r02 vector of the body
__device__ void r02(float r[], float angle,float L)
{
    r[0]=L*sin(angle)/2;
    r[1]=-1*L*cos(angle)/2;
    r[2]=0;
}

//Funtion to find the r01 position vector of the body
__device__ void r01(float r[], float angle,float L)
{
    r[0]=-1*L*sin(angle)/2;
    r[1]=L*cos(angle)/2;
    r[2]=0;
}

/**********************Matrix Operations*********************/

//Find the transpose of a 6x6 shifter matrix
__device__ void transpose(float S[6][6], int row, int col)
{
 if (row<3 && col>2)
 {
     S[col][row]=S[row][col];
     S[row][col]=0;
  }
}
//Multipy two 6x6 matrices, saving the result in C
__device__ void Mat66Mult(float A[6][6], float B[6][6], float C[6][6],int row, int col)
{
    float j = 0;
    int l=0;
    while (l<6)
    {
        j+=A[row][l]*B[l][col];
        l++;
    }
    syncthreads();
    C[row][col]=j;
    syncthreads();
}

//Multiply a 6x6 and a 6x1 matrix together.  The 6x1 is actually a 6x6 but 
//only the first collumn is used.
__device__ void Mat61Mult(float A[6][6], float B[6][6], float C[6][6],int row, int col)
{
    float j=0;
    int l =0;
    if (col==0)
    {
        while (l<6)
        {
            j+=A[row][l]*B[l][0];
            l++;
        }
        C[row][0]=j;
    }
}
/**********************Printing Functions**************************/

//Print a 6x6 matrix
__device__ void PrintMat66(float A[6][6], int nn )
{
   if (blockIdx.x==nn)
   {
    if (threadIdx.y+threadIdx.x==0)
    {
        
        printf("\\n[  %f\\t%f\\t%f\\t%f\\t%f\\t%f\\n%f\\t%f\\t%f\\t%f\\t%f\\t%f\\n%f\\t%f\\t%f\\t%f\\t%f\\t%f\\n%f\\t%f\\t%f\\t%f\\t%f\\t%f\\n%f\\t%f\\t%f\\t%f\\t%f\\t%f\\n%f\\t%f\\t%f\\t%f\\t",A[0][0],A[0][1],A[0][2],A[0][3],A[0][4],A[0][5],A[1][0],A[1][1],A[1][2],A[1][3],A[1][4],A[1][5],A[2][0],A[2][1],A[2][2],A[2][3],A[2][4],A[2][5],A[3][0],A[3][1],A[3][2],A[3][3],A[3][4],A[3][5],A[4][0],A[4][1],A[4][2],A[4][3],A[4][4],A[4][5],A[5][0],A[5][1],A[5][2],A[5][3]);
      printf("%f\\t%f ]\\n\\n\\n",A[5][4],A[5][5]);
      }
    }
}
"""
)
Initialize = mod.get_function("Initialize")
# Out:
# ---------------------------------------------------------------------------
# CompileError                              Traceback (most recent call last)
# <ipython-input-30-03596302aad4> in <module>()
#     381     }
#     382 }
# --> 383 """
#     384 )
#     385 Initialize = mod.get_function("Initialize")
#
# /home/mhans13/anaconda/envs/py33/lib/python3.3/site-packages/pycuda/compiler.py in __init__(self, source, nvcc, options, keep, no_extern_c, arch, code, cache_dir, include_dirs)
#     260
#     261         cubin = compile(source, nvcc, options, keep, no_extern_c,
# --> 262                 arch, code, cache_dir, include_dirs)
#     263
#     264         from pycuda.driver import module_from_buffer
#
# /home/mhans13/anaconda/envs/py33/lib/python3.3/site-packages/pycuda/compiler.py in compile(source, nvcc, options, keep, no_extern_c, arch, code, cache_dir, include_dirs)
#     250         options.append("-I"+i)
#     251
# --> 252     return compile_plain(source, options, keep, nvcc, cache_dir)
#     253
#     254
#
# /home/mhans13/anaconda/envs/py33/lib/python3.3/site-packages/pycuda/compiler.py in compile_plain(source, options, keep, nvcc, cache_dir)
#     132         from pycuda.driver import CompileError
#     133         raise CompileError("nvcc compilation of %s failed" % cu_file_path,
# --> 134                 cmdline, stdout=stdout.decode("utf-8"), stderr=stderr.decode("utf-8"))
#     135
#     136     if stdout or stderr:
#
# CompileError: nvcc compilation of /tmp/tmp777q7i/kernel.cu failed
# [command: nvcc --cubin -arch sm_30 -I/home/mhans13/anaconda/envs/py33/lib/python3.3/site-packages/pycuda/cuda kernel.cu]
# [stderr:
# kernel.cu(31): error: expected a ";"
#
# kernel.cu(36): error: identifier "i1" is undefined
#
# kernel.cu(69): error: identifier "get_W" is undefined
#
# kernel.cu(48): warning: variable "r223" was declared but never referenced
#
# kernel.cu(66): warning: variable "i23" was declared but never referenced
#
# kernel.cu(73): error: identifier "get_X_pend" is undefined
#
# kernel.cu(74): error: identifier "invert_X" is undefined
#
# kernel.cu(81): error: identifier "set_D_pend" is undefined
#
# kernel.cu(83): error: identifier "set_Dt_pend" is undefined
#
# kernel.cu(135): error: expected a ";"
#
# kernel.cu(156): warning: parsing restarts here after previous syntax error
#
# kernel.cu(157): error: identifier "i" is undefined
#
# kernel.cu(157): error: identifier "i1" is undefined
#
# kernel.cu(159): error: identifier "q" is undefined
#
# kernel.cu(159): error: identifier "state" is undefined
#
# kernel.cu(160): error: identifier "w" is undefined
#
# kernel.cu(176): error: identifier "Minv" is undefined
#
# kernel.cu(176): error: identifier "S" is undefined
#
# kernel.cu(176): error: identifier "m" is undefined
#
# kernel.cu(176): error: identifier "I" is undefined
#
# kernel.cu(176): error: identifier "Iindex" is undefined
#
# kernel.cu(186): error: identifier "z" is undefined
#
# kernel.cu(187): error: identifier "r" is undefined
#
# kernel.cu(187): error: identifier "q" is undefined
#
# kernel.cu(187): error: identifier "l" is undefined
#
# kernel.cu(191): error: identifier "Zetas" is undefined
#
# kernel.cu(191): error: identifier "i11" is undefined
#
# kernel.cu(198): error: identifier "i12" is undefined
#
# kernel.cu(202): error: identifier "w" is undefined
#
# kernel.cu(206): error: identifier "i13" is undefined
#
# kernel.cu(214): error: identifier "i22" is undefined
#
# kernel.cu(220): error: identifier "i21" is undefined
#
# kernel.cu(228): error: identifier "i23" is undefined
#
# 30 errors detected in the compilation of "/tmp/tmpxft_00000ea5_00000000-6_kernel.cpp1.ii".
# ]
# ERROR: An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))

# %%
q1init= np.pi/2
q2init=0
q1dotinit=0
q2dotinit=0
initialconditions=np.array(( q1init, q2init,q1dotinit,q2dotinit))

#number of bodies
n=2

#Bodies and Joints creation
B1=MB.Body()
B2=MB.Body()
B3=MB.Body()
B4=MB.Body()
J1=MB.Joint()
J2=MB.Joint()
B1.m=1.0
B2.m=1.0
B3.m=1.0
B4.m=1.0
B1.l=1.0
B2.l=1.0
B3.l=1.0
B4.l=1.0

B1.Inertia(B1.m*(B1.l**2)/12,1,B1.m*(B1.l**2)/12)
B2.Inertia(B2.m*(B2.l**2)/12,1,B2.m*(B2.l**2)/12)
B3.Inertia(B3.m*(B3.l**2)/12,1,B3.m*(B3.l**2)/12)
B4.Inertia(B4.m*(B4.l**2)/12,1,B4.m*(B4.l**2)/12)
J1.PDmatrix(np.array((0,0,1,0,0,0)),1)
J2.PDmatrix(np.array((0,0,1,0,0,0)),1)
bodies=[B1,B2]
bbs=[B3,B4]
joints=[J1,J2]

# %%
def init(b,x,n):   
    val1=0
    val2=np.zeros((3))
    val3=np.zeros((3))
    for k in range(0,n):
        val1=val1+x[k]
        b[k].C0=MBF.simdcm(val1,np.array((0,0,1)))
        val2=val2+np.array((0,0,x[k+n]))
        b[k].w=val2
        b[k].w1=np.array((0,0,x[k+n]))
        b[k].rs(b[k].l/2.0,np.array((0,-1,0)))
        b[k].Vcm=val3+np.cross(b[k].w,b[k].r10)
        val3=val3+np.cross(b[k].w,b[k].r12)
        b[k].Inertia2()#transformed inertia matrix
        b[k].Mmatrix()#Mass matrix and its inverse
        b[k].Forces(np.array((0,-1,0)))
        b[k].shifters()#S matrices
        b[k].zs()#zeta values

# %%
def pycudaAssembly(bodies):
      
    odd = 0
    newbds=[]
    if (len(bodies)%2)==0:
        for k in range (0,math.trunc(len(bodies)/2)):
            newbds.append(MB.Body())
    else:
        odd=1
        for k in range (0,math.trunc(len(bodies)/2)+1):
            newbds.append(MB.Body())
    oldZs_gpu = np.zeros((6,26*len(bodies)))
    #Will have to mess with this for larger numbers of bodies and odd numbers
    newZs_gpu = np.zeros((6,26*len(newbds))).astype(np.float32)
    for i in range (0,n):
        k=26*i
        oldZs_gpu[:,k:k+6]=bodies[i].z11
        oldZs_gpu[:,k+6:k+12]=bodies[i].z12
        oldZs_gpu[:,k+12]=bodies[i].z13
        oldZs_gpu[:,k+13:k+19]=bodies[i].z21
        oldZs_gpu[:,k+19,k+25]=bodies[i].z22
        oldZs_gpu[:,k+25]=bodies[i].z23
    oldZs_gpu=oldZs_gpu.astype(np.float32)

    Assemble(cuda.In(oldZs_gpu),cuda.Out(gpu_out),cuda.In(odd),block=(6,6,1),grid=(1,1,1))

    k=0
    index1 = 0
    while k<n:
        newbds[k].z11=newZs_gpu[:,index1:index1+6]
        index1 +=6
        newbds[k].z12=newZs_gpu[:,index1:index1+6]
        index1 +=6
        newbds[k].z13=newZs_gpu[:,index1]
        index1+=1
        newbds[k].z21=newZs_gpu[:,index1:index1+6]
        index1+=6
        newbds[k].z22=newZs_gpu[:,index1:index1+6]
        index1+=6
        newbds[k].z23=newZs_gpu[:,index1]
        index1+=1
        k+=1
    return newbds

# %%
init(bodies,initialconditions,n)

#Regular Assembly
newbds=MB.Body()
j=0 
#X, Q, and Y  are  intermediate quantities
newbds.X=np.dot(np.transpose(joints[2*j+1].D),np.dot(bodies[2*j+1].z11+bodies[2*j].z22,joints[2*j+1].D))
newbds.Xinv=np.linalg.inv(newbds.X)
newbds.W=np.dot(joints[2*j+1].D,np.dot(newbds.Xinv,np.transpose(joints[2*j+1].D)))
newbds.Y=np.dot(newbds.W,bodies[2*j].z23-bodies[2*j+1].z13)#ommitted pdot*u
#assemble the bodies based on the formulas
newbds.z11=bodies[2*j].z11-np.dot(bodies[2*j].z12,np.dot(newbds.W,bodies[2*j].z21))
newbds.z12=np.dot(bodies[2*j].z12,np.dot(newbds.W,bodies[2*j+1].z12))
newbds.z21=np.dot(bodies[2*j+1].z21,np.dot(newbds.W,bodies[2*j].z21))
newbds.z22=bodies[2*j+1].z22-np.dot(bodies[2*j+1].z21,np.dot(newbds.W,bodies[2*j+1].z12))
newbds.z13=bodies[2*j].z13-np.dot(bodies[2*j].z12,newbds.Y)
newbds.z23=bodies[2*j+1].z23+np.dot(bodies[2*j+1].z21,newbds.Y)

print(newbds.Xinv)
print(newbds.X)
#newbds2= pycudaAssembly(bodies)
# Out:
# [[  5.00000000e-01  -2.80648225e-17   0.00000000e+00   0.00000000e+00
#     0.00000000e+00]
#  [ -2.80648225e-17   4.16666667e-02   0.00000000e+00   0.00000000e+00
#     0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   5.00000000e-01  -2.29621275e-17
#     0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00  -2.29621275e-17   1.25000000e-01
#     0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     1.25000000e-01]]
# [[  2.00000000e+00   1.34711148e-15   0.00000000e+00   0.00000000e+00
#     0.00000000e+00]
#  [  1.34711148e-15   2.40000000e+01   0.00000000e+00   0.00000000e+00
#     0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   2.00000000e+00   3.67394040e-16
#     0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   3.67394040e-16   8.00000000e+00
#     0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     8.00000000e+00]]
